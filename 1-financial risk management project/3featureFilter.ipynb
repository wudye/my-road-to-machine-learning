# %%
import pandas as pd
import toad
data = pd.read_csv('data/germancredit.csv')
data.replace({'good':0,'bad':1},inplace=True)
data.shape
# Out:
# (1000, 21)

# %%
data['creditability'] = data['creditability'].astype(int)

selected_data, drop_list = toad.selection.select(data,target='creditability',empty=0.5,iv=0.05,corr=0.7,return_drop=True)

# %%
drop_list
# Out:
# {'empty': array([], dtype=float64),
#  'iv': <StringArray>
#  [     'installment.rate.in.percentage.of.disposable.income',
#                                    'personal.status.and.sex',
#                                'other.debtors.or.guarantors',
#                                    'present.residence.since',
#                    'number.of.existing.credits.at.this.bank',
#                                                        'job',
#   'number.of.people.being.liable.to.provide.maintenance.for',
#                                                  'telephone',
#                                             'foreign.worker']
#  Length: 9, dtype: str,
#  'corr': <StringArray>
#  []
#  Length: 0, dtype: str}

# %%
from boruta import BorutaPy
import joblib
from sklearn.ensemble import RandomForestClassifier

# %%
pd_data = joblib.load('data/train_woe.pkl')
# Out:
# E:\anaconda\envs\heima\Lib\pickle.py:1632: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd_data = joblib.load('data/train_woe.pkl')
#
# File E:\anaconda\envs\heima\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
# ...

# %%
pd_data = joblib.load('data/train_woe.pkl')
# Out:
# E:\anaconda\envs\heima\Lib\pickle.py:1632: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pd_data = joblib.load('data/train_woe.pkl')
#
# File E:\anaconda\envs\heima\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
# ...

# %%
print(pd.__version__)
# Out:
# 3.0.0

# %%
import pickle
pd_data = pd.read_pickle('data/train_woe.pkl')
# Out:
# E:\anaconda\envs\heima\Lib\site-packages\pandas\compat\pickle_compat.py:80: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)
# E:\anaconda\envs\heima\Lib\site-packages\pandas\compat\pickle_compat.py:80: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)

# %%
pd_data.shape
# Out:
# (215257, 79)

# %%
pd_data.head()
# Out:
#         SK_ID_CURR  TARGET  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# 125406      245429       0         0.610118                    0.016406
# 8155        109510       0        -0.366495                   -0.410334
# 154053      278546       0         0.038650                    0.016406
# 300963      448668       0        -0.366495                   -0.158446
# 269546      412373       0        -0.366495                   -0.410334
#
#         DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  \
# 125406    0.301190       0.092078          -0.099822         0.275679
# 8155     -0.440745      -0.608958           0.164707         0.193847
# 154053    0.301190       0.371651           0.075169         0.060654
# 300963    0.301190      -0.171601           0.075169        -0.057870
# 269546   -0.051704      -0.171601          -0.099822        -0.297834
#
#         REGION_RATING_CLIENT_W_CITY  REG_CITY_NOT_LIVE_CITY  ...  \
# ...

# %%
pd_x = pd_data.drop(['SK_ID_CURR', 'TARGET'], axis=1)
x = pd_x.values
y = pd_data['TARGET'].values

# %%
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
feat_selector = BorutaPy(rf, n_estimators='auto', random_state=1, max_iter=3)
feat_selector.fit(x, y)
"""
from sklearn.ensemble import GradientBoostingClassifier

# 使用 GradientBoosting 或 LightGBM 更快
rf = GradientBoostingClassifier(
    n_estimators=50,
    max_depth=3,
    random_state=1,
    verbose=1
)

feat_selector = BorutaPy(
    rf,
    n_estimators='auto',
    random_state=1,
    max_iter=5,      # 减少迭代
    verbose=2       # 显示进度
)

feat_selector.fit(x, y)

"""
# Out:
# BorutaPy(estimator=RandomForestClassifier(class_weight='balanced', max_depth=5,
#                                           n_estimators=248, n_jobs=-1,
#                                           random_state=RandomState(MT19937) at 0x1717CB0A440),
#          max_iter=3, n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x1717CB0A440)

# %%
feat_selector.support_
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
feat_selector.ranking_
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 3, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
pd_x.columns[feat_selector.support_]
# Out:
# Index([], dtype='object')

# %%
pd_feature_select = pd.DataFrame({'feature_name':pd_x.columns,'choose or':feat_selector.support_})
pd_feature_select[pd_feature_select['choose or']==False]
# Out:
#                                         feature_name  choose or
# 0                                    AMT_GOODS_PRICE      False
# 1                         REGION_POPULATION_RELATIVE      False
# 2                                         DAYS_BIRTH      False
# 3                                      DAYS_EMPLOYED      False
# 4                                  DAYS_REGISTRATION      False
# ..                                               ...        ...
# 72                 p_PRODUCT_COMBINATION_Card Street      False
# 73           p_PRODUCT_COMBINATION_Cash Street: high      False
# 74           p_PRODUCT_COMBINATION_Cash X-Sell: high      False
# 75            p_PRODUCT_COMBINATION_Cash X-Sell: low      False
# 76  p_PRODUCT_COMBINATION_POS industry with interest      False
#
# [77 rows x 2 columns]

# %%
from pandas import DataFrame
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
def check_vif(df:DataFrame):
    lst_col = df.columns
    X = np.matrix(df)
    VIF_list = [variance_inflation_factor(X,i) for i in range(X.shape[1])]
    VIF = pd.DataFrame({'feature name':lst_col,'VIF':VIF_list})
    return VIF

# %%
from sklearn.svm import LinearSVC
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE

# %%
X,y = load_iris(return_X_y=True)
lscv = LinearSVC(C=0.01)
rfe = RFE(estimator=lscv, n_features_to_select=2)
rfe.fit(X,y)
print(rfe.support_)
# Out:
# [False  True  True False]

# %%
rfe.ranking_
# Out:
# array([3, 1, 1, 2])

# %%
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X, y)
model = SelectFromModel(lsvc, prefit=True)

X_new = model.transform(X)
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X, y)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(X)
X_new.shape
# Out:
# E:\anaconda\envs\heima\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# E:\anaconda\envs\heima\Lib\site-packages\sklearn\svm\_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# (150, 3)
